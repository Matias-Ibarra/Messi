# %%
import pandas as pd
df = pd.read_csv('data/messi_goles.csv')
df
# Out:
#     Season            Competition     Matchday      Date Venue  \
# 0    04/05                 LaLiga           34  05-01/05     H
# 1    05/06  UEFA Champions League  Group Stage  11-02/05     H
# 2    05/06                 LaLiga           13  11/27/05     H
# 3    05/06                 LaLiga           19   1/15/06     H
# 4    05/06                 LaLiga           20   1/22/06     H
# ..     ...                    ...          ...       ...   ...
# 699  22/23                Ligue 1           21    2/1/23     A
# 700  22/23                Ligue 1           22    2/4/23     H
# 701  22/23                Ligue 1           24   2/19/23     H
# 702  22/23                Ligue 1           25   2/26/23     A
# 703  22/23                Ligue 1           26    3/4/23     H
#
#                     Club              Opponent Result Playing_Position Minute  \
# 0           FC Barcelona     Albacete Balompie   2:00               CF   90+1
# 1           FC Barcelona  Panathinaikos Athens   5:00               RW     34
# 2           FC Barcelona      Racing Santander   4:01               RW     51
# 3           FC Barcelona       Athletic Bilbao   2:01               RW     50
# 4           FC Barcelona      Deportivo Alaves   2:00               CF     82
# ..                   ...                   ...    ...              ...    ...
# 699  Paris Saint-Germain       Montpellier HSC    1:3               SS     72
# 700  Paris Saint-Germain           FC Toulouse    2:1               SS     58
# 701  Paris Saint-Germain            LOSC Lille    4:3               CF   90+5
# 702  Paris Saint-Germain   Olympique Marseille    0:3               CF     29
# 703  Paris Saint-Germain             FC Nantes    4:2               CF     12
#
#     At_score               Type        Goal_assist
# 0       2:00   Left-footed shot  Ronaldinho Gaacho
# 1       3:00   Left-footed shot                NaN
# 2       2:00   Left-footed shot        Samuel Etoo
# 3       2:01   Left-footed shot    Mark van Bommel
# 4       2:00   Left-footed shot  Ronaldinho Gaacho
# ..       ...                ...                ...
# 699      0:2   Left-footed shot        Fabián Ruiz
# 700      2:1   Left-footed shot      Achraf Hakimi
# 701      4:3   Direct free kick                 \t
# 702      0:2  Right-footed shot      Kylian Mbappé
# 703      1:0   Left-footed shot                NaN
#
# [704 rows x 13 columns]

# %%
df['Opponent'].nunique()
# Out:
# 98

# %%
# Buscando información en la web noto que la cantidad de equipos diferentes a los que le marco goles difieren con los obtenidos en el dataset.
# Busco equipos repetidos:
equipos = list(df['Opponent'].unique())
print(equipos)
# Out:
# ['Albacete Balompie', 'Panathinaikos Athens', 'Racing Santander', 'Athletic Bilbao', 'Deportivo Alaves', 'RCD Mallorca', 'Real Zaragoza', 'Real Betis Balompie', 'Celta de Vigo', 'CA Osasuna', 'SV Werder Bremen', 'Sevilla FC', 'Real Madrid', 'Recreativo Huelva', 'Deportivo de La Coruaa', 'Getafe CF', 'Atletico de Madrid', 'RCD Espanyol Barcelona', 'Gimnastic de Tarragona', 'Olympique Lyon', 'Levante UD', 'VfB Stuttgart', 'UD Almera', 'Rangers FC', 'Celtic FC', 'Valencia CF', 'Sporting GijÃ³n', 'Shakhtar Donetsk', 'FC Basel 1893', 'Malaga CF', 'Benidorm CD', 'Sporting CP', 'CD Numancia', 'Bayern Munich', 'Manchester United', 'Dynamo Kyiv', 'Cultural Leonesa', 'CF Atlante', 'Club Estudiantes de La Plata', 'CD Tenerife', 'Real Valladolid CF', 'Arsenal FC', 'Villarreal CF', 'FC Copenhagen', 'Club Atletico de Ceuta', 'Real Sociedad', 'Hercules CF', 'FC Porto', 'BATE Borisov', 'FC Viktoria Plzen', 'AC Milan', 'Rayo Vallecano', 'Santos FC', 'Bayer 04 Leverkusen', 'Granada CF', 'Spartak Moscow', 'CÃ³rdoba CF', 'Paris Saint-Germain', 'Ajax Amsterdam', 'Manchester City', 'Elche CF', 'SD Eibar', 'APOEL Nicosia', 'AS Roma', 'CA River Plate', 'CD Leganes', 'Borussia MÃ¶nchengladbach', 'UD Las Palmas', 'Juventus FC', 'Olympiacos Piraeus', 'Chelsea FC', 'Girona FC', 'SD Huesca', 'PSV Eindhoven', 'Tottenham Hotspur', 'Liverpool FC', 'SK Slavia Prague', 'Borussia Dortmund', 'SSC Napoli', 'Ferencvarosi TC', 'Cadiz CF', 'RB Leipzig', 'FC Nantes', 'Club Brugge KV', 'LOSC Lille', 'FC Lorient', 'RC Lens', 'Montpellier', 'Clermont Foot', 'Maccabi Haifa', 'OGC Nice', 'SL Benfica', 'AC Ajaccio', 'ESTAC Troyes', 'Angers SCO', 'Montpellier HSC', 'FC Toulouse', 'Olympique Marseille']

# %%
# Montpellier y Montpellier HSC son el mismo club
df['Opponent'].replace("Montpellier", "Montpellier HSC", inplace=True)
df['Opponent'].nunique()
# Out:
# 97

# %%
#df.to_csv('messi_goles_limpio.csv', index = False)
