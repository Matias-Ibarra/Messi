# %%
import pandas as pd
ccaa = pd.read_csv('data/comunidades_limpio.csv')
df = pd.read_csv('data/messi_goles.csv')
df_con_ccaa = pd.merge(df, ccaa)
df_con_ccaa
# Out:
#     Season            Competition     Matchday      Date Venue  \
# 0    04/05                 LaLiga           34  05-01/05     H
# 1    05/06  UEFA Champions League  Group Stage  11-02/05     H
# 2    10/11  UEFA Champions League  Group Stage   9/14/10     H
# 3    10/11  UEFA Champions League  Group Stage   9/14/10     H
# 4    10/11  UEFA Champions League  Group Stage  11/24/10     A
# ..     ...                    ...          ...       ...   ...
# 698  22/23                Ligue 1           18   1/11/23     H
# 699  22/23                Ligue 1           21    2/1/23     A
# 700  22/23                Ligue 1           21    2/1/23     A
# 701  22/23                Ligue 1           22    2/4/23     H
# 702  22/23                Ligue 1           25   2/26/23     A
#
#                     Club              Opponent Result Playing_Position Minute  \
# 0           FC Barcelona     Albacete Balompie   2:00               CF   90+1
# ...

# %%
#df_con_ccaa.to_csv('messi_goles_con_caa.csv', index = False)
